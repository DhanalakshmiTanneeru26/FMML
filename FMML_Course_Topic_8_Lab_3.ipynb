# %% [markdown]
# <a href="https://colab.research.google.com/github/DhanalakshmiTanneeru26/FMML-LABS-AND-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 10:35:27--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   112MB/s    in 0.6s
#
# 2024-03-31 10:35:28 (112 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26323  1609.08675v1  Many recent advancements in Computer Vision ar...    cs
# 39599  1610.01400v1  We investigate in this work a versatile convex...    cs
# 40416   1005.2364v2  The concept of overfitting in model selection ...    cs
# 36453   1401.4593v1  Recent research has shown that surprisingly ri...    cs
# 1127   1711.09667v1  We present an end-to-end learning method for c...    cs
# ...             ...                                                ...   ...
# 2580   1606.04414v3  In many applications of black-box optimization...  stat
# 22807  1707.03530v1  We propose a method for estimating coefficient...  stat
# 35864   1301.7377v1  This paper (1)shows that the best supported cu...    cs
# 35576   0908.3091v2  For natural and artificial systems with some s...    cs
# 2861   1803.00885v3  Training neural networks involves finding mini...  stat
#
#                                                    title  year  \
# 26323  YouTube-8M: A Large-Scale Video Classification...  2016
# 39599  Convex Histogram-Based Joint Image Segmentatio...  2016
# 40416  A Short Introduction to Model Selection, Kolmo...  2010
# 36453  Location-Based Reasoning about Complex Multi-A...  2014
# 1127   DeepChess: End-to-End Deep Neural Network for ...  2017
# ...                                                  ...   ...
# 2580   The Parallel Knowledge Gradient Method for Bat...  2016
# 22807  A Cluster Fusion Penalty for Grouping Response...  2017
# 35864  Psychological and Normative Theories of Causal...  2013
# 35576  Computational Understanding and Manipulation o...  2009
# 2861   Essentially No Barriers in Neural Network Ener...  2018
#
#                                                 keywords
# 26323  [advancements, attributed, inexpensive, commod...
# 39599  [investigate, versatile, framework, segmentati...
# 40416  [overfitting, selection, explained, demonstrat...
# 36453  [surprisingly, concentrated, individuals, stat...
# 1127   [knowledge, particular, knowledge, regarding, ...
# ...                                                  ...
# 2580   [applications, optimization, simultaneously, e...
# 22807  [estimating, coefficients, multivariate, regre...
# 35864  [supported, psychological, influence, variatio...
# 35576  [artificial, structure, computational, underst...
# 2861   [dimensional, knowledge, structure, landscape,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26323    [advancements, attributed, inexpensive, commod...
# 39599    [investigate, versatile, framework, segmentati...
# 40416    [overfitting, selection, explained, demonstrat...
# 36453    [surprisingly, concentrated, individuals, stat...
# 1127     [knowledge, particular, knowledge, regarding, ...
#                                ...
# 26298    [estimation, utilizing, convolutional, applica...
# 28980    [applications, discovered, including, performi...
# 7577     [interpreting, predictions, important, attribu...
# 6204     [important, applications, including, reconstru...
# 32371    [regarding, dependency, achievable, framework,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8623 words.
# Out of those 4521 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5d77cf56-71be-448f-b4fd-c35717fadb8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d77cf56-71be-448f-b4fd-c35717fadb8d")) {                    Plotly.newPlot(                        "5d77cf56-71be-448f-b4fd-c35717fadb8d",                        [{"x":["automated","including","classification","exploring","commodity","convergence","understanding","computing","available","strategies","annotated","comparable","inexpensive","generated","advancements","evaluated","vocabulary","attributed","recognizable","precision","representation","immediately","evaluation","introduce","tensorflow","compressed","annotation","baselines","benchmark","approaches","efficiently","distributions","versatile","algorithms","regularized","multidimensional","estimated","histograms","segmented","different","transport","statistical","histogram","framework","investigate","segmentation","functions","referring","considered","supervised","introduction","kolmogorov","selection","background","explained","information","description","minimization","demonstrated","overfitting","explanation","providing","complexity","discussion","relationships","probabilistically","impossible","alternatives","explicitly","constraints","properties","performed","cooperative","activities","behaviors","successfully","concentrated","successful","recognizing","automatically","unsuccessful","occurrences","individual","intentions","augmented","logically","illustrate","surprisingly","reasoning","executions","important","considering","demonstrate","recognition","interactions","relational","occurrence","performance","computationally","attempted","capturing","individuals","competitive","significantly","regarding","resulting","particular","knowledge","experiments","positions","automatic","unsupervised","pretraining","favorable","incorporated","developed","combination","algorithm","empirically","interactive","generalization","theoretically","structural","consistency","committee","increases","transform","modifications","increasing","stochastic","applications","implemented","attention","adversarial","multiplicative","advantage","systematic","distributed","expressions","establish","numerical","empirical","challenges","procedure","variances","numerically","variables","degradation","detection","stationarity","probability","decreasing","asymptotic","initially","detecting","statistics","optimality","observations","optimization","investigated","designing","superiority","consistently","subproblems","algorithmic","flexibility","nonsmooth","experiences","performing","nonconvex","direction","guarantee","theoretical","programming","motivated","guaranteed","challenging","practical","iterations","alternating","conditions","synthesized","reproducing","functional","generalizing","hypothesis","vectorial","continuous","reproduction","furthermore","generalized","therefore","consideration","pointwise","representer","principles","objective","relaxation","disjunctive","efficient"],"y":[84,236,514,44,8,121,161,128,288,93,71,87,12,173,11,140,28,13,1,76,389,9,258,329,7,21,73,60,219,428,156,113,4,649,35,13,77,13,23,709,9,148,24,530,152,223,198,9,125,195,35,4,182,86,15,703,75,55,87,15,28,76,235,30,58,2,17,27,56,141,196,113,15,38,24,85,8,76,40,168,2,12,108,6,38,2,81,29,136,2,353,59,562,391,86,31,38,856,94,9,48,43,108,268,43,167,275,339,595,32,168,167,5,16,25,199,117,826,85,37,104,42,70,56,3,48,82,26,98,116,426,82,169,94,19,115,39,93,35,62,76,149,105,110,3,7,126,16,355,9,164,10,21,17,96,60,21,77,306,48,39,28,41,7,48,20,3,14,69,5,56,40,176,124,56,34,264,128,31,28,130,19,9,30,20,64,3,108,4,146,69,148,32,4,1,30,157,26,9,400],"type":"bar"},{"x":["automated","including","classification","exploring","commodity","convergence" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4521,), (4521, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3586497890295359);'>Understanding</span> <span style=''>the</span> <span style=''>Loss</span> <span style=''>Surface</span> <span style=''>of</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>for</span> <span style=''>Binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <br/><br/><span style=''>It</span> <span style=''>is</span> <span style=''>widely</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>conjectured</span> <span style=''>that</span> <span style=''>the</span> <span style=''>reason</span> <span style=''>that</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successful</span> <span style=''>because</span> <span style=''>all</span> <span style=''>local</span> <span style=''>minima</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>similar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>for</span> <span style=''>example</span> <span style=''>see</span> <span style=''>(LeCun</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2015</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Choromanska</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2015</span> <span style=''>Dauphin</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2014)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Performance</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>measured</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>two</span> <span style=''>metrics</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>single</span> <span style=''>layered</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>for</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>and</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>under</span> <span style=''>which</span> <span style=''>the</span> <span style=''>training</span> <span style=''>error</span> <span style=''>is</span> <span style=''>zero</span> <span style=''>at</span> <span style=''>all</span> <span style=''>local</span> <span style=''>minima</span> <span style=''>of</span> <span style=''>a</span> <span style=''>smooth</span> <span style=''>hinge</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>are</span> <span style=''>roughly</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>following</span> <span style=''>form</span> <span style=''>the</span> <span style=''>neurons</span> <span style=''>have</span> <span style=''>to</span> <span style=''>be</span> <span style=''>strictly</span> <span style=''>convex</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3125);'>surrogate</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>PAC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learnability</span> <span style=''>under</span> <span style=''>non</span> <span style=''>atomic</span> <span style=''>measures</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>by</span> <span style=''>Vidyasagar</span> <br/><br/><span style=''>In</span> <span style=''>response</span> <span style=''>to</span> <span style=''>a</span> <span style=''>1997</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>M</span> <span style=''>Vidyasagar</span> <span style=''>we</span> <span style=''>state</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>for</span> <span style=''>PAC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learnability</span> <span style=''>of</span> <span style=''>a</span> <span style=''>concept</span> <span style=''>class</span> <span style=''>mathscr</span> <span style=''>C</span> <span style=''>under</span> <span style=''>the</span> <span style=''>family</span> <span style=''>of</span> <span style=''>all</span> <span style=''>non</span> <span style=''>atomic</span> <span style=''>(diffuse)</span> <span style=''>measures</span> <span style=''>on</span> <span style=''>the</span> <span style=''>domain</span> <span style=''>Omega</span> <span style=''>The</span> <span style=''>uniform</span> <span style=''>Glivenko</span> <span style=''>Cantelli</span> <span style=''>property</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>non</span> <span style=''>atomic</span> <span style=''>measures</span> <span style=''>is</span> <span style=''>no</span> <span style=''>longer</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learnability</span> <span style=''>cannot</span> <span style=''>in</span> <span style=''>general</span> <span style=''>be</span> <span style=''>expected</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>is</span> <span style=''>stated</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>VC(mathscr</span> <span style=''>Cmathrmmodomega</span> <span style=''>1)</span> <span style=''>which</span> <span style=''>we</span> <span style=''>call</span> <span style=''>the</span> <span style=''>VC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>mathscr</span> <span style=''>C</span> <span style=''>modulo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>countable</span> <span style=''>sets</span> <span style=''>The</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>is</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>thickening</span> <span style=''>up</span> <span style=''>single</span> <span style=''>points</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style=''>of</span> <span style=''>VC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncountable</span> <span style=''>clusters</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Equivalently</span> <span style=''>VC(mathscr</span> <span style=''>Cmoddomega</span> <span style=''>1)leq</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Appropriate</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>Inappropriate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Techniques</span> <br/><br/><span style=''>Mode</span> <span style=''>also</span> <span style=''>called</span> <span style=''>MAP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>mean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style=''>median</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>are</span> <span style=''>examined</span> <span style=''>here</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3278688524590165);'>determine</span> <span style=''>when</span> <span style=''>they</span> <span style=''>can</span> <span style=''>be</span> <span style=''>safely</span> <span style=''>used</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>posterior)</span> <span style=''>cost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style='background-color:rgba(255, 0, 0, 0.34);'>estimates</span> <span style=''>(These</span> <span style=''>are</span> <span style=''>all</span> <span style=''>Bayes</span> <span style='background-color:rgba(255, 0, 0, 0.4017094017094016);'>procedures</span> <span style=''>using</span> <span style=''>the</span> <span style=''>mode</span> <span style=''>mean</span> <span style=''>or</span> <span style=''>median</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6682926829268293);'>posterior</span> <span style=''>distribution)</span> <span style=''>It</span> <span style=''>is</span> <span style=''>found</span> <span style=''>that</span> <span style=''>modal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>only</span> <span style=''>returns</span> <span style=''>cost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style='background-color:rgba(255, 0, 0, 0.34);'>estimates</span> <span style=''>when</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>is</span> <span style=''>0</span> <span style=''>t</span> <span style=''>If</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>is</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>distance</span> <span style=''>then</span> <span style=''>mean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>only</span> <span style=''>returns</span> <span style=''>cost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style='background-color:rgba(255, 0, 0, 0.34);'>estimates</span> <span style=''>when</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>is</span> <span style=''>squared</span> <span style=''>distance</span> <span style=''>from</span> <span style=''>the</span> <span style=''>true</span> <span style=''>value</span> <span style=''>and</span> <span style=''>median</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>only</span> <span style=''>returns</span> <span style=''>cost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style='background-color:rgba(255, 0, 0, 0.34);'>estimates</span> <span style=''>when</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>ts</span> <span style=''>the</span> <span style=''>distance</span> <span style=''>from</span> <span style=''>the</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Projection</span> <span style=''>Free</span> <span style=''>Rank</span> <span style=''>Drop</span> <span style=''>Steps</span> <br/><br/><span style=''>The</span> <span style=''>Frank</span> <span style=''>Wolfe</span> <span style=''>(FW)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>has</span> <span style=''>been</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>in</span> <span style=''>solving</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>problems</span> <span style=''>since</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style=''>require</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>However</span> <span style=''>FW</span> <span style=''>often</span> <span style=''>yields</span> <span style=''>high</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intermediate</span> <span style=''>iterates</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>in</span> <span style=''>time</span> <span style=''>and</span> <span style=''>space</span> <span style=''>costs</span> <span style=''>for</span> <span style=''>large</span> <span style=''>problems</span> <span style=''>To</span> <span style=''>address</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>rank</span> <span style=''>drop</span> <span style=''>method</span> <span style=''>for</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>problems</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>generate</span> <span style=''>descent</span> <span style=''>steps</span> <span style=''>that</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decreases</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintaining</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>throughout</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>Moreover</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>to</span> <span style=''>ensure</span> <span style=''>that</span> <span style=''>the</span> <span style=''>rank</span> <span style=''>drop</span> <span style=''>step</span> <span style=''>is</span> <span style=''>also</span> <span style=''>feasible</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style=''>readily</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporated</span> <span style=''>into</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>free</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>method</span> <span style=''>eg</span> <span style=''>Frank</span> <span style=''>Wolfe</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>in ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12094184801997859)
# 	experimental (0.13628255440599357)
# 	processing (0.09917945058865502)
# 	segmentation (0.07955761683910097)
# 	representation (0.13877987870139136)
# 	different (0.2529432750624331)
# 	information (0.25080271138066357)
# 	detection (0.12665001783803068)
# 	convolutional (0.13307170888333927)
# 	recognition (0.13949339992864787)
#
# Some Statistics words are:
# 	synthetic (0.12769153730595895)
# 	variational (0.10515773660490736)
# 	variables (0.1412118177265899)
# 	algorithm (0.3915873810716074)
# 	statistical (0.1527290936404607)
# 	estimation (0.17626439659489235)
# 	dimensional (0.18177265898848272)
# 	distribution (0.18928392588883325)
# 	inference (0.2128192288432649)
# 	regression (0.1897846770155233)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a6fa922d-193f-49d7-aac3-e94a1930e715" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6fa922d-193f-49d7-aac3-e94a1930e715")) {                    Plotly.newPlot(                        "a6fa922d-193f-49d7-aac3-e94a1930e715",                        [{"x":["automated","including","classification","exploring","commodity","convergence","understanding","computing","available","strategies","annotated","comparable","inexpensive","generated","advancements","evaluated","vocabulary","attributed","recognizable","precision","representation","immediately","evaluation","introduce","tensorflow","compressed","annotation","baselines","benchmark","approaches","efficiently","distributions","versatile","algorithms","regularized","multidimensional","estimated","histograms","segmented","different","transport","statistical","histogram","framework","investigate","segmentation","functions","referring","considered","supervised","introduction","kolmogorov","selection","background","explained","information","description","minimization","demonstrated","overfitting","explanation","providing","complexity","discussion","relationships","probabilistically","impossible","alternatives","explicitly","constraints","properties","performed","cooperative","activities","behaviors","successfully","concentrated","successful","recognizing","automatically","unsuccessful","occurrences","individual","intentions","augmented","logically","illustrate","surprisingly","reasoning","executions","important","considering","demonstrate","recognition","interactions","relational","occurrence","performance","computationally","attempted","capturing","individuals","competitive","significantly","regarding","resulting","particular","knowledge","experiments","positions","automatic","unsupervised","pretraining","favorable","incorporated","developed","combination","algorithm","empirically","interactive","generalization","theoretically","structural","consistency","committee","increases","transform","modifications","increasing","stochastic","applications","implemented","attention","adversarial","multiplicative","advantage","systematic","distributed","expressions","establish","numerical","empirical","challenges","procedure","variances","numerically","variables","degradation","detection","stationarity","probability","decreasing","asymptotic","initially","detecting","statistics","optimality","observations","optimization","investigated","designing","superiority","consistently","subproblems","algorithmic","flexibility","nonsmooth","experiences","performing","nonconvex","direction","guarantee","theoretical","programming","motivated","guaranteed","challenging","practical","iterations","alternating","conditions","synthesized","reproducing","functional","generalizing","hypothesis","vectorial","continuous","reproduction","furthermore","generalized","therefore","consideration","pointwise","representer","principles","objective","relaxation","disjunctive","efficient","tradeoffs","procedures","coordinate","conjunctive","objectives","interpretable","contribution","principled","interpretability","characterize","prediction","collection","recovering","mechanism","associated","canonical","keypoints","quantitative","deformation","deformable","additionally","applicability","parameterized","qualitative","leveraging","categories","appearance","reconstruction","supervision","structure","incorporating","represented","predicted","collections","inference","existence","application","experimental","presented","balancing","reinforcement","maximized","embeddings","improvements","approximately","experimenting","moderation","computational","structured","decomposing","equations","effective","primitive","implement","trun ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	logarithmically
# 	maximizer
# 	appreciate
# 	subsample
# 	memberships
# 	diagnosed
# 	projectorg
# 	inspecting
# 	realizations
# 	thermostat
# 	thermostats
# 	visualisation
# 	ellipsoid
# 	precisions
# 	particulars
# 	collinearity
# 	reparametrization
# 	penalised
# 	epigenomics
# 	normalised
# Some words which never appear in Statistics papers:
# 	unsuccessful
# 	intentions
# 	logically
# 	executions
# 	keypoints
# 	deformation
# 	moderation
# 	deceptive
# 	downsampling
# 	localizing
# 	simplicial
# 	photographs
# 	isolating
# 	justifications
# 	axiomatization
# 	formalisms
# 	substance
# 	contrasted
# 	sigmoidal
# 	outperformance

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.072102239562533e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7541666666666667
